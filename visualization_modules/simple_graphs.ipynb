# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../datasets/exercicio_imoveis.csv", sep=";", decimal=",")
df.columns
# df.head()
# Out:
# Index(['AREA', 'QUARTOS', 'VAGAS DE GARAGEM', 'VALOR'], dtype='object')

# %%
plt.plot([1, 2, 3, 4, 5, 6], [2, 3, 4, 1, 5, 2])

# %%
plt.scatter(df["AREA"], df["VALOR"])

# %%
plt.hist(df["VALOR"], 5)
# Out:
# (array([ 4.,  3.,  6., 12.,  5.]),
#  array([5409.64 , 6326.284, 7242.928, 8159.572, 9076.216, 9992.86 ]),
#  <BarContainer object of 5 artists>)

# %%
plt.bar(df["QUARTOS"], 10)
# Out:
# <BarContainer object of 30 artists>

# %%
plt.pcolor(df)

# %%
sns.regplot(x="AREA", y="VALOR", data=df)
# Out:
# <Axes: xlabel='AREA', ylabel='VALOR'>

# %%
sns.residplot(data=df, x="AREA", y="VALOR")
# Out:
# <Axes: xlabel='AREA', ylabel='VALOR'>

# %%
sns.kdeplot(df)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.displot(df)
